# %% [markdown]
# ### Stock Analysis
#
# The key idea is to use financial statements, news, tweets, forumns to dictate Share price. So we need to do the following
# * WebScrape:
#     * financial statements
#     * share price
#     * tweets
#     * news
# * Pre-process & clean:
# * EDA:
# * Sentiment Analysis on: news, tweets, and forumns
# * check for significance of attributes

# %% [markdown]
# ## WebScrape

# %%
# These codes are taken with reference to https://towardsdatascience.com/web-scraping-for-accounting-analysis-using-python-part-1-b5fc016a1c9a

import pandas as pd
from bs4 import BeautifulSoup
import urllib.request as ur

# %%
# Enter a stock symbol
index= 'QAN.AX'
# URL link 
url_is = 'https://sg.finance.yahoo.com/quote/' + index + '/financials?p=' + index
url_bs = 'https://sg.finance.yahoo.com/quote/' + index +'/balance-sheet?p=' + index
url_cf = 'https://sg.finance.yahoo.com/quote/' + index + '/cash-flow?p='+ index

# %%
#Read the data
read_data_is = ur.urlopen(url_is).read() 
read_data_bs = ur.urlopen(url_bs).read()
read_data_cf = ur.urlopen(url_cf).read()

soup_is= BeautifulSoup(read_data_is,'lxml')
soup_bs= BeautifulSoup(read_data_bs,'lxml')
soup_cf= BeautifulSoup(read_data_cf,'lxml')

# %%
def ex_dat(emp_ls, soup_data, num_col):
    for i in soup_data.find_all('div'):
        emp_ls.append(i.string)
#     emp_ls = [e for e in emp_ls if e not in ('Operating Expenses', 'Non-recurring Events')]
    # Remove non div
    emp_ls = list(filter(None,emp_ls))
    
    # Remove non important scraped data
    emp_ls = emp_ls[10:]
    
    # Remove the 'Quarterly'
    emp_ls.pop(1)
    emp_ls = list(zip(*[iter(emp_ls)]*num_col))
    df = pd.DataFrame(emp_ls[0:])
    df.drop(df.tail(1).index, inplace=True)
    
    
    df.columns = df.iloc[0] # Name columns to first row of dataframe
    df = df.iloc[1:,] # start to read 1st row
    df = df.T # transpose dataframe

    df.columns = df.iloc[0] #Name columns to first row of dataframe
    df.drop(df.index[0],inplace=True) #Drop first index row
    
    df.index.name = '' # Remove the index name
    
    return df

# %%
ls_is = [] # Create empty list
ls_bs = []
ls_cf = []


for l in soup_is.find_all('div'): 
  #Find all data structure that is ‘div’
  ls_is.append(l.string) # add each element one by one to the list

    
ls_is = [e for e in ls_is if e not in ('Operating Expenses','Non-recurring Events')] # Exclude those columns

# %%
ls_bs = ex_dat(ls_bs, soup_bs, 5)
ls_cf = ex_dat(ls_cf, soup_cf, 6)

# %%
ls_bs
# Out:
# Annual     Cash and cash equivalents Other short-term investments Total cash  \
#
# 30/06/2020                 3,520,000                      216,000  3,736,000
# 30/06/2019                 2,157,000                      334,000  2,491,000
# 30/06/2018                 1,694,000                      474,000  2,168,000
# 30/06/2017                 1,775,000                      100,000  1,775,000
#
# Annual     Net receivables Inventory Other current assets  \
#
# 30/06/2020         335,000   306,000               72,000
# 30/06/2019         975,000   364,000               75,000
# 30/06/2018         908,000   351,000              167,000
# 30/06/2017         666,000   351,000               97,000
#
# Annual     Total current assets Gross property, plant and equipment  \
#
# 30/06/2020            4,952,000                          30,697,000
# 30/06/2019            4,193,000                          27,850,000
# 30/06/2018            3,712,000                          12,851,000
# 30/06/2017            3,119,000                          25,940,000
#
# Annual     Accumulated depreciation Net property, plant and equipment  \
#
# 30/06/2020              -17,531,000                        13,166,000
# 30/06/2019              -14,873,000                        12,977,000
# 30/06/2018                        -                        12,851,000
# 30/06/2017              -13,687,000                        12,253,000
#
# Annual                        ...                      \
#                               ...
# 30/06/2020                    ...
# 30/06/2019                    ...
# 30/06/2018                    ...
# 30/06/2017                    ...
#
# Annual     Deferred tax liabilities Deferred revenues  \
#
# 30/06/2020                        -         2,256,000
# 30/06/2019                  847,000         1,466,000
# 30/06/2018                  910,000         1,446,000
# 30/06/2017                  353,000         1,424,000
#
# Annual     Other long-term liabilities Total non-current liabilities  \
#
# 30/06/2020                      47,000                    10,196,000
# 30/06/2019                      48,000                     7,365,000
# 30/06/2018                      25,000                     7,092,000
# 30/06/2017                      56,000                     6,586,000
#
# Annual     Total liabilities Common stock Retained earnings  \
#
# 30/06/2020        18,500,000    3,053,000        -1,357,000
# 30/06/2019        15,941,000    1,719,000         1,603,000
# 30/06/2018        14,688,000    2,393,000         1,084,000
# 30/06/2017        13,681,000    3,053,000           472,000
#
# Annual     Accumulated other comprehensive income Total stockholders' equity  \
#
# 30/06/2020                               -173,000                  1,523,000
# 30/06/2019                                111,000                  3,433,000
# 30/06/2018                                479,000                  3,956,000
# 30/06/2017                                 12,000                  3,537,000
#
# Annual     Total liabilities and stockholders' equity
#
# 30/06/2020                                 20,026,000
# 30/06/2019                                 19,377,000
# 30/06/2018                                 18,647,000
# 30/06/2017                                 17,221,000
#
# [4 rows x 32 columns]

# %%
ls_cf
# Out:
# Annual     Investments in property, plant and equipment Acquisitions, net  \
#
# ttm                                          -1,944,000                 -
# 30/06/2020                                   -1,549,000                 -
# 30/06/2019                                   -1,944,000                 -
# 30/06/2018                                   -1,959,000                 -
# 30/06/2017                                   -1,368,000                 0
#
# Annual     Purchases of investments Sales/maturities of investments  \
#
# ttm                         -60,000                               -
# 30/06/2020                  -24,000                               -
# 30/06/2019                  -60,000                               -
# 30/06/2018                   -2,000                               -
# 30/06/2017                  -16,000                               0
#
# Annual     Other investing activities Net cash used for investing activities  \
#
# ttm                          -130,000                             -1,651,000
# 30/06/2020                    -48,000                             -1,571,000
# 30/06/2019                   -130,000                             -1,651,000
# 30/06/2018                   -274,000                             -2,201,000
# 30/06/2017                   -696,000                             -2,046,000
#
# Annual     Debt repayment Common stock issued Common stock repurchased  \
#
# ttm              -744,000           1,342,000                 -735,000
# 30/06/2020       -625,000           1,342,000                 -448,000
# 30/06/2019       -744,000                   -                 -735,000
# 30/06/2018       -802,000                   -                 -913,000
# 30/06/2017       -453,000                   -                 -564,000
#
# Annual     Dividends paid Other financing activities  \
#
# ttm              -363,000                   -367,000
# 30/06/2020       -204,000                   -367,000
# 30/06/2019       -363,000                          -
# 30/06/2018       -249,000                          -
# 30/06/2017       -264,000                      8,000
#
# Annual     Net cash used provided by (used for) financing activities  \
#
# ttm                                                  -705,000
# 30/06/2020                                          1,853,000
# 30/06/2019                                           -705,000
# 30/06/2018                                         -1,296,000
# 30/06/2017                                           -854,000
#
# Annual     Net change in cash Cash at beginning of period  \
#
# ttm                   451,000                   1,694,000
# 30/06/2020          1,365,000                   2,157,000
# 30/06/2019            451,000                   1,694,000
# 30/06/2018            -84,000                   1,775,000
# 30/06/2017           -196,000                   1,980,000
#
# Annual     Cash at end of period Capital expenditure Free cash flow
#
# ttm                    2,157,000          -1,944,000        863,000
# 30/06/2020             3,520,000          -1,549,000       -466,000
# 30/06/2019             2,157,000          -1,944,000        863,000
# 30/06/2018             1,694,000          -1,959,000      1,454,000
# 30/06/2017             1,775,000          -1,368,000      1,336,000

# %%
ls_is = list(filter(None,ls_is))

# %%
ls_is
# Out:
# ["No matching results for ''",
#  'Tip: Try a valid symbol or a specific company name for relevant results',
#  ' react-empty: 2 ',
#  ' react-empty: 2 ',
#  'Qantas Airways Limited (QAN.AX)',
#  'ASX - ASX Delayed Price. Currency in AUD',
#  'At close:  4:11PM AEDT',
#  'Income statement',
#  'Balance sheet',
#  'Cash flow',
#  'Annual',
#  'Quarterly',
#  'ttm',
#  '30/06/2020',
#  '30/06/2019',
#  '30/06/2018',
#  '30/06/2017',
#  'Total revenue',
#  '17,597,000',
#  '14,054,000',
#  '17,597,000',
#  '16,628,000',
#  '15,680,000',
#  'Cost of revenue',
#  '7,841,000',
#  '6,415,000',
#  '7,841,000',
#  '6,828,000',
#  '6,475,000',
#  'Gross profit',
#  '9,756,000',
#  '7,639,000',
#  '9,756,000',
#  '9,800,000',
#  '9,205,000',
#  'Selling general and administrative',
#  '5,514,000',
#  '4,287,000',
#  '5,514,000',
#  '5,500,000',
#  '5,335,000',
#  'Total operating expenses',
#  '8,888,000',
#  '8,212,000',
#  '8,888,000',
#  '8,639,000',
#  '8,174,000',
#  'Operating income or loss',
#  '868,000',
#  '-573,000',
#  '868,000',
#  '1,161,000',
#  '1,031,000',
#  'Interest expense',
#  '232,000',
#  '208,000',
#  '232,000',
#  '230,000',
#  '235,000',
#  'Total other income/expenses net',
#  '582,000',
#  '-1,864,000',
#  '582,000',
#  '412,000',
#  '346,000',
#  'Income before tax',
#  '1,265,000',
#  '-2,708,000',
#  '1,265,000',
#  '1,391,000',
#  '1,181,000',
#  'Income tax expense',
#  '374,000',
#  '-744,000',
#  '374,000',
#  '411,000',
#  '328,000',
#  'Income from continuing operations',
#  '891,000',
#  '-1,964,000',
#  '891,000',
#  '980,000',
#  '853,000',
#  'Net income',
#  '891,000',
#  '-1,964,000',
#  '891,000',
#  '980,000',
#  '852,000',
#  'Net income available to common shareholders',
#  '891,000',
#  '-1,964,000',
#  '891,000',
#  '980,000',
#  '852,000',
#  'Basic EPS',
#  '-',
#  '-',
#  '0.55',
#  '0.56',
#  '0.46',
#  'Diluted EPS',
#  '-',
#  '-',
#  '0.54',
#  '0.56',
#  '0.46',
#  'Basic average shares',
#  '-',
#  '-',
#  '1,634,000',
#  '1,756,000',
#  '1,808,226',
#  'Diluted average shares',
#  '-',
#  '-',
#  '1,637,868',
#  '1,756,000',
#  '1,808,226',
#  'EBITDA',
#  '-',
#  '-455,000',
#  '3,162,000',
#  '3,149,000',
#  '2,798,000',
#  'document.write(\'<a href="https://sg.as.y.atwola.com/?adlink|5113.1|4871878|0|0|AdId=-40;BnId=0;itime=559660172;kvmn=y403334;kvssp=ssp;kvrs=ydotcom:qsp:finance:ver:pt:utility:site:pct;kvpgcolo=sg3;kvy%2Dbucket=finance%2Dsg%2Den%2Dsg%2Ddef;kvadtc%5Fdvmktname=unknown;kvadtc%5Fdvosplt=unknown;kvadtc%5Fdvbrand=unknown;kvadtc%5Fdvtype=unknown;kvadtc%5Fdvmodel=unknown;kvrepo%5Fdvosplt=unknown;kvadtc%5Fdvosversion=UNKNOWN;kvadtc%5Fcrbrand=wifi%5F;kvadtc%5Fcrmcc=UNKNOWN;kvadtc%5Fcrmnc=UNKNOWN;kvadtc%5Fcontype=wifi;gdpr=0;adclntid=1004;spaceid=1187335917;" target=_top><img src="https://aka-cdn.adtechus.com/images/ATCollapse.gif" border=0 alt="AOL Ad" width="1" height="1" ></a>\');\n var adcount_4871878_1_=new Image();\nadcount_4871878_1_.src="https://sg.as.y.atwola.com/adcount|2.0|5113.1|4871878|0|0|AdId=-40;BnId=0;ct=1374990969;st=1450;adcid=1;itime=559660172;reqtype=5;;impref=1606559661131164490;imprefseq=67567253142383133;imprefts=1606559661;adclntid=1004;spaceid=1187335917;adposition=FSRVY;lmsid=;revshare=pt%253Autility%253Bsite%253Afinance%253Bver%253Aydotcom%253Bpct%253Aqsp;pvid=fUPawgAAAADL8pzkhCIjJZgSCvH411_CJ60ADRTs;sectionid=96364561;kvmn=y403334;kvssp=ssp;kvrs=ydotcom:qsp:finance:ver:pt:utility:site:pct;kvpgcolo=sg3;kvy%2Dbucket=finance%2Dsg%2Den%2Dsg%2Ddef;kvadtc%5Fdvmktname=unknown;kvadtc%5Fdvosplt=unknown;kvadtc%5Fdvbrand=unknown;kvadtc%5Fdvtype=unknown;kvadtc%5Fdvmodel=unknown;kvrepo%5Fdvosplt=unknown;kvadtc%5Fdvosversion=UNKNOWN;kvadtc%5Fcrbrand=wifi%5F;kvadtc%5Fcrmcc=UNKNOWN;kvadtc%5Fcrmnc=UNKNOWN;kvadtc%5Fcontype=wifi;gdpr=0;"; \n',
#  'document.write(\'<a href="https://sg.as.y.atwola.com/?adlink|5113.1|4871878|0|0|AdId=-40;BnId=0;itime=559660172;kvmn=y403334;kvssp=ssp;kvrs=ydotcom:qsp:finance:ver:pt:utility:site:pct;kvpgcolo=sg3;kvy%2Dbucket=finance%2Dsg%2Den%2Dsg%2Ddef;kvadtc%5Fdvmktname=unknown;kvadtc%5Fdvosplt=unknown;kvadtc%5Fdvbrand=unknown;kvadtc%5Fdvtype=unknown;kvadtc%5Fdvmodel=unknown;kvrepo%5Fdvosplt=unknown;kvadtc%5Fdvosversion=UNKNOWN;kvadtc%5Fcrbrand=wifi%5F;kvadtc%5Fcrmcc=UNKNOWN;kvadtc%5Fcrmnc=UNKNOWN;kvadtc%5Fcontype=wifi;gdpr=0;adclntid=1004;spaceid=1187335917;" target=_top><img src="https://aka-cdn.adtechus.com/images/ATCollapse.gif" border=0 alt="AOL Ad" width="1" height="1" ></a>\');\n var adcount_4871878_1_=new Image();\nadcount_4871878_1_.src="https://sg.as.y.atwola.com/adcount|2.0|5113.1|4871878|0|0|AdId=-40;BnId=0;ct=1374990969;st=1450;adcid=1;itime=559660172;reqtype=5;;impref=1606559661131164490;imprefseq=67567253142383133;imprefts=1606559661;adclntid=1004;spaceid=1187335917;adposition=FSRVY;lmsid=;revshare=pt%253Autility%253Bsite%253Afinance%253Bver%253Aydotcom%253Bpct%253Aqsp;pvid=fUPawgAAAADL8pzkhCIjJZgSCvH411_CJ60ADRTs;sectionid=96364561;kvmn=y403334;kvssp=ssp;kvrs=ydotcom:qsp:finance:ver:pt:utility:site:pct;kvpgcolo=sg3;kvy%2Dbucket=finance%2Dsg%2Den%2Dsg%2Ddef;kvadtc%5Fdvmktname=unknown;kvadtc%5Fdvosplt=unknown;kvadtc%5Fdvbrand=unknown;kvadtc%5Fdvtype=unknown;kvadtc%5Fdvmodel=unknown;kvrepo%5Fdvosplt=unknown;kvadtc%5Fdvosversion=UNKNOWN;kvadtc%5Fcrbrand=wifi%5F;kvadtc%5Fcrmcc=UNKNOWN;kvadtc%5Fcrmnc=UNKNOWN;kvadtc%5Fcontype=wifi;gdpr=0;"; \n',
#  'document.write(\'<a href="https://sg.as.y.atwola.com/?adlink|5113.1|4871878|0|0|AdId=-40;BnId=0;itime=559660172;kvmn=y403334;kvssp=ssp;kvrs=ydotcom:qsp:finance:ver:pt:utility:site:pct;kvpgcolo=sg3;kvy%2Dbucket=finance%2Dsg%2Den%2Dsg%2Ddef;kvadtc%5Fdvmktname=unknown;kvadtc%5Fdvosplt=unknown;kvadtc%5Fdvbrand=unknown;kvadtc%5Fdvtype=unknown;kvadtc%5Fdvmodel=unknown;kvrepo%5Fdvosplt=unknown;kvadtc%5Fdvosversion=UNKNOWN;kvadtc%5Fcrbrand=wifi%5F;kvadtc%5Fcrmcc=UNKNOWN;kvadtc%5Fcrmnc=UNKNOWN;kvadtc%5Fcontype=wifi;gdpr=0;adclntid=1004;spaceid=1187335917;" target=_top><img src="https://aka-cdn.adtechus.com/images/ATCollapse.gif" border=0 alt="AOL Ad" width="1" height="1" ></a>\');\n var adcount_4871878_1_=new Image();\nadcount_4871878_1_.src="https://sg.as.y.atwola.com/adcount|2.0|5113.1|4871878|0|0|AdId=-40;BnId=0;ct=1374990969;st=1450;adcid=1;itime=559660172;reqtype=5;;impref=1606559661131164490;imprefseq=67567253142383133;imprefts=1606559661;adclntid=1004;spaceid=1187335917;adposition=FSRVY;lmsid=;revshare=pt%253Autility%253Bsite%253Afinance%253Bver%253Aydotcom%253Bpct%253Aqsp;pvid=fUPawgAAAADL8pzkhCIjJZgSCvH411_CJ60ADRTs;sectionid=96364561;kvmn=y403334;kvssp=ssp;kvrs=ydotcom:qsp:finance:ver:pt:utility:site:pct;kvpgcolo=sg3;kvy%2Dbucket=finance%2Dsg%2Den%2Dsg%2Ddef;kvadtc%5Fdvmktname=unknown;kvadtc%5Fdvosplt=unknown;kvadtc%5Fdvbrand=unknown;kvadtc%5Fdvtype=unknown;kvadtc%5Fdvmodel=unknown;kvrepo%5Fdvosplt=unknown;kvadtc%5Fdvosversion=UNKNOWN;kvadtc%5Fcrbrand=wifi%5F;kvadtc%5Fcrmcc=UNKNOWN;kvadtc%5Fcrmnc=UNKNOWN;kvadtc%5Fcontype=wifi;gdpr=0;"; \n',
#  'document.write(\'<a href="https://sg.as.y.atwola.com/?adlink|5113.1|4871878|0|0|AdId=-40;BnId=0;itime=559660172;kvmn=y403334;kvssp=ssp;kvrs=ydotcom:qsp:finance:ver:pt:utility:site:pct;kvpgcolo=sg3;kvy%2Dbucket=finance%2Dsg%2Den%2Dsg%2Ddef;kvadtc%5Fdvmktname=unknown;kvadtc%5Fdvosplt=unknown;kvadtc%5Fdvbrand=unknown;kvadtc%5Fdvtype=unknown;kvadtc%5Fdvmodel=unknown;kvrepo%5Fdvosplt=unknown;kvadtc%5Fdvosversion=UNKNOWN;kvadtc%5Fcrbrand=wifi%5F;kvadtc%5Fcrmcc=UNKNOWN;kvadtc%5Fcrmnc=UNKNOWN;kvadtc%5Fcontype=wifi;gdpr=0;adclntid=1004;spaceid=1187335917;" target=_top><img src="https://aka-cdn.adtechus.com/images/ATCollapse.gif" border=0 alt="AOL Ad" width="1" height="1" ></a>\');\n var adcount_4871878_1_=new Image();\nadcount_4871878_1_.src="https://sg.as.y.atwola.com/adcount|2.0|5113.1|4871878|0|0|AdId=-40;BnId=0;ct=1374990969;st=1450;adcid=1;itime=559660172;reqtype=5;;impref=1606559661131164490;imprefseq=67567253142383133;imprefts=1606559661;adclntid=1004;spaceid=1187335917;adposition=FSRVY;lmsid=;revshare=pt%253Autility%253Bsite%253Afinance%253Bver%253Aydotcom%253Bpct%253Aqsp;pvid=fUPawgAAAADL8pzkhCIjJZgSCvH411_CJ60ADRTs;sectionid=96364561;kvmn=y403334;kvssp=ssp;kvrs=ydotcom:qsp:finance:ver:pt:utility:site:pct;kvpgcolo=sg3;kvy%2Dbucket=finance%2Dsg%2Den%2Dsg%2Ddef;kvadtc%5Fdvmktname=unknown;kvadtc%5Fdvosplt=unknown;kvadtc%5Fdvbrand=unknown;kvadtc%5Fdvtype=unknown;kvadtc%5Fdvmodel=unknown;kvrepo%5Fdvosplt=unknown;kvadtc%5Fdvosversion=UNKNOWN;kvadtc%5Fcrbrand=wifi%5F;kvadtc%5Fcrmcc=UNKNOWN;kvadtc%5Fcrmnc=UNKNOWN;kvadtc%5Fcontype=wifi;gdpr=0;"; \n',
#  ' react-empty: 2 ',
#  ' react-empty: 2 ',
#  '© 2020 Verizon Media. All rights reserved.']

# %%
ls_is = ls_is[10:]

# %%
ls_is.pop(1)
ls_is
# Out:
# ['Annual',
#  'ttm',
#  '30/06/2020',
#  '30/06/2019',
#  '30/06/2018',
#  '30/06/2017',
#  'Total revenue',
#  '17,597,000',
#  '14,054,000',
#  '17,597,000',
#  '16,628,000',
#  '15,680,000',
#  'Cost of revenue',
#  '7,841,000',
#  '6,415,000',
#  '7,841,000',
#  '6,828,000',
#  '6,475,000',
#  'Gross profit',
#  '9,756,000',
#  '7,639,000',
#  '9,756,000',
#  '9,800,000',
#  '9,205,000',
#  'Selling general and administrative',
#  '5,514,000',
#  '4,287,000',
#  '5,514,000',
#  '5,500,000',
#  '5,335,000',
#  'Total operating expenses',
#  '8,888,000',
#  '8,212,000',
#  '8,888,000',
#  '8,639,000',
#  '8,174,000',
#  'Operating income or loss',
#  '868,000',
#  '-573,000',
#  '868,000',
#  '1,161,000',
#  '1,031,000',
#  'Interest expense',
#  '232,000',
#  '208,000',
#  '232,000',
#  '230,000',
#  '235,000',
#  'Total other income/expenses net',
#  '582,000',
#  '-1,864,000',
#  '582,000',
#  '412,000',
#  '346,000',
#  'Income before tax',
#  '1,265,000',
#  '-2,708,000',
#  '1,265,000',
#  '1,391,000',
#  '1,181,000',
#  'Income tax expense',
#  '374,000',
#  '-744,000',
#  '374,000',
#  '411,000',
#  '328,000',
#  'Income from continuing operations',
#  '891,000',
#  '-1,964,000',
#  '891,000',
#  '980,000',
#  '853,000',
#  'Net income',
#  '891,000',
#  '-1,964,000',
#  '891,000',
#  '980,000',
#  '852,000',
#  'Net income available to common shareholders',
#  '891,000',
#  '-1,964,000',
#  '891,000',
#  '980,000',
#  '852,000',
#  'Basic EPS',
#  '-',
#  '-',
#  '0.55',
#  '0.56',
#  '0.46',
#  'Diluted EPS',
#  '-',
#  '-',
#  '0.54',
#  '0.56',
#  '0.46',
#  'Basic average shares',
#  '-',
#  '-',
#  '1,634,000',
#  '1,756,000',
#  '1,808,226',
#  'Diluted average shares',
#  '-',
#  '-',
#  '1,637,868',
#  '1,756,000',
#  '1,808,226',
#  'EBITDA',
#  '-',
#  '-455,000',
#  '3,162,000',
#  '3,149,000',
#  '2,798,000',
#  'document.write(\'<a href="https://sg.as.y.atwola.com/?adlink|5113.1|4871878|0|0|AdId=-40;BnId=0;itime=559660172;kvmn=y403334;kvssp=ssp;kvrs=ydotcom:qsp:finance:ver:pt:utility:site:pct;kvpgcolo=sg3;kvy%2Dbucket=finance%2Dsg%2Den%2Dsg%2Ddef;kvadtc%5Fdvmktname=unknown;kvadtc%5Fdvosplt=unknown;kvadtc%5Fdvbrand=unknown;kvadtc%5Fdvtype=unknown;kvadtc%5Fdvmodel=unknown;kvrepo%5Fdvosplt=unknown;kvadtc%5Fdvosversion=UNKNOWN;kvadtc%5Fcrbrand=wifi%5F;kvadtc%5Fcrmcc=UNKNOWN;kvadtc%5Fcrmnc=UNKNOWN;kvadtc%5Fcontype=wifi;gdpr=0;adclntid=1004;spaceid=1187335917;" target=_top><img src="https://aka-cdn.adtechus.com/images/ATCollapse.gif" border=0 alt="AOL Ad" width="1" height="1" ></a>\');\n var adcount_4871878_1_=new Image();\nadcount_4871878_1_.src="https://sg.as.y.atwola.com/adcount|2.0|5113.1|4871878|0|0|AdId=-40;BnId=0;ct=1374990969;st=1450;adcid=1;itime=559660172;reqtype=5;;impref=1606559661131164490;imprefseq=67567253142383133;imprefts=1606559661;adclntid=1004;spaceid=1187335917;adposition=FSRVY;lmsid=;revshare=pt%253Autility%253Bsite%253Afinance%253Bver%253Aydotcom%253Bpct%253Aqsp;pvid=fUPawgAAAADL8pzkhCIjJZgSCvH411_CJ60ADRTs;sectionid=96364561;kvmn=y403334;kvssp=ssp;kvrs=ydotcom:qsp:finance:ver:pt:utility:site:pct;kvpgcolo=sg3;kvy%2Dbucket=finance%2Dsg%2Den%2Dsg%2Ddef;kvadtc%5Fdvmktname=unknown;kvadtc%5Fdvosplt=unknown;kvadtc%5Fdvbrand=unknown;kvadtc%5Fdvtype=unknown;kvadtc%5Fdvmodel=unknown;kvrepo%5Fdvosplt=unknown;kvadtc%5Fdvosversion=UNKNOWN;kvadtc%5Fcrbrand=wifi%5F;kvadtc%5Fcrmcc=UNKNOWN;kvadtc%5Fcrmnc=UNKNOWN;kvadtc%5Fcontype=wifi;gdpr=0;"; \n',
#  'document.write(\'<a href="https://sg.as.y.atwola.com/?adlink|5113.1|4871878|0|0|AdId=-40;BnId=0;itime=559660172;kvmn=y403334;kvssp=ssp;kvrs=ydotcom:qsp:finance:ver:pt:utility:site:pct;kvpgcolo=sg3;kvy%2Dbucket=finance%2Dsg%2Den%2Dsg%2Ddef;kvadtc%5Fdvmktname=unknown;kvadtc%5Fdvosplt=unknown;kvadtc%5Fdvbrand=unknown;kvadtc%5Fdvtype=unknown;kvadtc%5Fdvmodel=unknown;kvrepo%5Fdvosplt=unknown;kvadtc%5Fdvosversion=UNKNOWN;kvadtc%5Fcrbrand=wifi%5F;kvadtc%5Fcrmcc=UNKNOWN;kvadtc%5Fcrmnc=UNKNOWN;kvadtc%5Fcontype=wifi;gdpr=0;adclntid=1004;spaceid=1187335917;" target=_top><img src="https://aka-cdn.adtechus.com/images/ATCollapse.gif" border=0 alt="AOL Ad" width="1" height="1" ></a>\');\n var adcount_4871878_1_=new Image();\nadcount_4871878_1_.src="https://sg.as.y.atwola.com/adcount|2.0|5113.1|4871878|0|0|AdId=-40;BnId=0;ct=1374990969;st=1450;adcid=1;itime=559660172;reqtype=5;;impref=1606559661131164490;imprefseq=67567253142383133;imprefts=1606559661;adclntid=1004;spaceid=1187335917;adposition=FSRVY;lmsid=;revshare=pt%253Autility%253Bsite%253Afinance%253Bver%253Aydotcom%253Bpct%253Aqsp;pvid=fUPawgAAAADL8pzkhCIjJZgSCvH411_CJ60ADRTs;sectionid=96364561;kvmn=y403334;kvssp=ssp;kvrs=ydotcom:qsp:finance:ver:pt:utility:site:pct;kvpgcolo=sg3;kvy%2Dbucket=finance%2Dsg%2Den%2Dsg%2Ddef;kvadtc%5Fdvmktname=unknown;kvadtc%5Fdvosplt=unknown;kvadtc%5Fdvbrand=unknown;kvadtc%5Fdvtype=unknown;kvadtc%5Fdvmodel=unknown;kvrepo%5Fdvosplt=unknown;kvadtc%5Fdvosversion=UNKNOWN;kvadtc%5Fcrbrand=wifi%5F;kvadtc%5Fcrmcc=UNKNOWN;kvadtc%5Fcrmnc=UNKNOWN;kvadtc%5Fcontype=wifi;gdpr=0;"; \n',
#  'document.write(\'<a href="https://sg.as.y.atwola.com/?adlink|5113.1|4871878|0|0|AdId=-40;BnId=0;itime=559660172;kvmn=y403334;kvssp=ssp;kvrs=ydotcom:qsp:finance:ver:pt:utility:site:pct;kvpgcolo=sg3;kvy%2Dbucket=finance%2Dsg%2Den%2Dsg%2Ddef;kvadtc%5Fdvmktname=unknown;kvadtc%5Fdvosplt=unknown;kvadtc%5Fdvbrand=unknown;kvadtc%5Fdvtype=unknown;kvadtc%5Fdvmodel=unknown;kvrepo%5Fdvosplt=unknown;kvadtc%5Fdvosversion=UNKNOWN;kvadtc%5Fcrbrand=wifi%5F;kvadtc%5Fcrmcc=UNKNOWN;kvadtc%5Fcrmnc=UNKNOWN;kvadtc%5Fcontype=wifi;gdpr=0;adclntid=1004;spaceid=1187335917;" target=_top><img src="https://aka-cdn.adtechus.com/images/ATCollapse.gif" border=0 alt="AOL Ad" width="1" height="1" ></a>\');\n var adcount_4871878_1_=new Image();\nadcount_4871878_1_.src="https://sg.as.y.atwola.com/adcount|2.0|5113.1|4871878|0|0|AdId=-40;BnId=0;ct=1374990969;st=1450;adcid=1;itime=559660172;reqtype=5;;impref=1606559661131164490;imprefseq=67567253142383133;imprefts=1606559661;adclntid=1004;spaceid=1187335917;adposition=FSRVY;lmsid=;revshare=pt%253Autility%253Bsite%253Afinance%253Bver%253Aydotcom%253Bpct%253Aqsp;pvid=fUPawgAAAADL8pzkhCIjJZgSCvH411_CJ60ADRTs;sectionid=96364561;kvmn=y403334;kvssp=ssp;kvrs=ydotcom:qsp:finance:ver:pt:utility:site:pct;kvpgcolo=sg3;kvy%2Dbucket=finance%2Dsg%2Den%2Dsg%2Ddef;kvadtc%5Fdvmktname=unknown;kvadtc%5Fdvosplt=unknown;kvadtc%5Fdvbrand=unknown;kvadtc%5Fdvtype=unknown;kvadtc%5Fdvmodel=unknown;kvrepo%5Fdvosplt=unknown;kvadtc%5Fdvosversion=UNKNOWN;kvadtc%5Fcrbrand=wifi%5F;kvadtc%5Fcrmcc=UNKNOWN;kvadtc%5Fcrmnc=UNKNOWN;kvadtc%5Fcontype=wifi;gdpr=0;"; \n',
#  'document.write(\'<a href="https://sg.as.y.atwola.com/?adlink|5113.1|4871878|0|0|AdId=-40;BnId=0;itime=559660172;kvmn=y403334;kvssp=ssp;kvrs=ydotcom:qsp:finance:ver:pt:utility:site:pct;kvpgcolo=sg3;kvy%2Dbucket=finance%2Dsg%2Den%2Dsg%2Ddef;kvadtc%5Fdvmktname=unknown;kvadtc%5Fdvosplt=unknown;kvadtc%5Fdvbrand=unknown;kvadtc%5Fdvtype=unknown;kvadtc%5Fdvmodel=unknown;kvrepo%5Fdvosplt=unknown;kvadtc%5Fdvosversion=UNKNOWN;kvadtc%5Fcrbrand=wifi%5F;kvadtc%5Fcrmcc=UNKNOWN;kvadtc%5Fcrmnc=UNKNOWN;kvadtc%5Fcontype=wifi;gdpr=0;adclntid=1004;spaceid=1187335917;" target=_top><img src="https://aka-cdn.adtechus.com/images/ATCollapse.gif" border=0 alt="AOL Ad" width="1" height="1" ></a>\');\n var adcount_4871878_1_=new Image();\nadcount_4871878_1_.src="https://sg.as.y.atwola.com/adcount|2.0|5113.1|4871878|0|0|AdId=-40;BnId=0;ct=1374990969;st=1450;adcid=1;itime=559660172;reqtype=5;;impref=1606559661131164490;imprefseq=67567253142383133;imprefts=1606559661;adclntid=1004;spaceid=1187335917;adposition=FSRVY;lmsid=;revshare=pt%253Autility%253Bsite%253Afinance%253Bver%253Aydotcom%253Bpct%253Aqsp;pvid=fUPawgAAAADL8pzkhCIjJZgSCvH411_CJ60ADRTs;sectionid=96364561;kvmn=y403334;kvssp=ssp;kvrs=ydotcom:qsp:finance:ver:pt:utility:site:pct;kvpgcolo=sg3;kvy%2Dbucket=finance%2Dsg%2Den%2Dsg%2Ddef;kvadtc%5Fdvmktname=unknown;kvadtc%5Fdvosplt=unknown;kvadtc%5Fdvbrand=unknown;kvadtc%5Fdvtype=unknown;kvadtc%5Fdvmodel=unknown;kvrepo%5Fdvosplt=unknown;kvadtc%5Fdvosversion=UNKNOWN;kvadtc%5Fcrbrand=wifi%5F;kvadtc%5Fcrmcc=UNKNOWN;kvadtc%5Fcrmnc=UNKNOWN;kvadtc%5Fcontype=wifi;gdpr=0;"; \n',
#  ' react-empty: 2 ',
#  ' react-empty: 2 ',
#  '© 2020 Verizon Media. All rights reserved.']

# %%
is_data = list(zip(*[iter(ls_is)]*6))

# %%
is_data
# Out:
# [('Annual', 'ttm', '30/06/2020', '30/06/2019', '30/06/2018', '30/06/2017'),
#  ('Total revenue',
#   '17,597,000',
#   '14,054,000',
#   '17,597,000',
#   '16,628,000',
#   '15,680,000'),
#  ('Cost of revenue',
#   '7,841,000',
#   '6,415,000',
#   '7,841,000',
#   '6,828,000',
#   '6,475,000'),
#  ('Gross profit',
#   '9,756,000',
#   '7,639,000',
#   '9,756,000',
#   '9,800,000',
#   '9,205,000'),
#  ('Selling general and administrative',
#   '5,514,000',
#   '4,287,000',
#   '5,514,000',
#   '5,500,000',
#   '5,335,000'),
#  ('Total operating expenses',
#   '8,888,000',
#   '8,212,000',
#   '8,888,000',
#   '8,639,000',
#   '8,174,000'),
#  ('Operating income or loss',
#   '868,000',
#   '-573,000',
#   '868,000',
#   '1,161,000',
#   '1,031,000'),
#  ('Interest expense', '232,000', '208,000', '232,000', '230,000', '235,000'),
#  ('Total other income/expenses net',
#   '582,000',
#   '-1,864,000',
#   '582,000',
#   '412,000',
#   '346,000'),
#  ('Income before tax',
#   '1,265,000',
#   '-2,708,000',
#   '1,265,000',
#   '1,391,000',
#   '1,181,000'),
#  ('Income tax expense',
#   '374,000',
#   '-744,000',
#   '374,000',
#   '411,000',
#   '328,000'),
#  ('Income from continuing operations',
#   '891,000',
#   '-1,964,000',
#   '891,000',
#   '980,000',
#   '853,000'),
#  ('Net income', '891,000', '-1,964,000', '891,000', '980,000', '852,000'),
#  ('Net income available to common shareholders',
#   '891,000',
#   '-1,964,000',
#   '891,000',
#   '980,000',
#   '852,000'),
#  ('Basic EPS', '-', '-', '0.55', '0.56', '0.46'),
#  ('Diluted EPS', '-', '-', '0.54', '0.56', '0.46'),
#  ('Basic average shares', '-', '-', '1,634,000', '1,756,000', '1,808,226'),
#  ('Diluted average shares', '-', '-', '1,637,868', '1,756,000', '1,808,226'),
#  ('EBITDA', '-', '-455,000', '3,162,000', '3,149,000', '2,798,000'),
#  ('document.write(\'<a href="https://sg.as.y.atwola.com/?adlink|5113.1|4871878|0|0|AdId=-40;BnId=0;itime=559660172;kvmn=y403334;kvssp=ssp;kvrs=ydotcom:qsp:finance:ver:pt:utility:site:pct;kvpgcolo=sg3;kvy%2Dbucket=finance%2Dsg%2Den%2Dsg%2Ddef;kvadtc%5Fdvmktname=unknown;kvadtc%5Fdvosplt=unknown;kvadtc%5Fdvbrand=unknown;kvadtc%5Fdvtype=unknown;kvadtc%5Fdvmodel=unknown;kvrepo%5Fdvosplt=unknown;kvadtc%5Fdvosversion=UNKNOWN;kvadtc%5Fcrbrand=wifi%5F;kvadtc%5Fcrmcc=UNKNOWN;kvadtc%5Fcrmnc=UNKNOWN;kvadtc%5Fcontype=wifi;gdpr=0;adclntid=1004;spaceid=1187335917;" target=_top><img src="https://aka-cdn.adtechus.com/images/ATCollapse.gif" border=0 alt="AOL Ad" width="1" height="1" ></a>\');\n var adcount_4871878_1_=new Image();\nadcount_4871878_1_.src="https://sg.as.y.atwola.com/adcount|2.0|5113.1|4871878|0|0|AdId=-40;BnId=0;ct=1374990969;st=1450;adcid=1;itime=559660172;reqtype=5;;impref=1606559661131164490;imprefseq=67567253142383133;imprefts=1606559661;adclntid=1004;spaceid=1187335917;adposition=FSRVY;lmsid=;revshare=pt%253Autility%253Bsite%253Afinance%253Bver%253Aydotcom%253Bpct%253Aqsp;pvid=fUPawgAAAADL8pzkhCIjJZgSCvH411_CJ60ADRTs;sectionid=96364561;kvmn=y403334;kvssp=ssp;kvrs=ydotcom:qsp:finance:ver:pt:utility:site:pct;kvpgcolo=sg3;kvy%2Dbucket=finance%2Dsg%2Den%2Dsg%2Ddef;kvadtc%5Fdvmktname=unknown;kvadtc%5Fdvosplt=unknown;kvadtc%5Fdvbrand=unknown;kvadtc%5Fdvtype=unknown;kvadtc%5Fdvmodel=unknown;kvrepo%5Fdvosplt=unknown;kvadtc%5Fdvosversion=UNKNOWN;kvadtc%5Fcrbrand=wifi%5F;kvadtc%5Fcrmcc=UNKNOWN;kvadtc%5Fcrmnc=UNKNOWN;kvadtc%5Fcontype=wifi;gdpr=0;"; \n',
#   'document.write(\'<a href="https://sg.as.y.atwola.com/?adlink|5113.1|4871878|0|0|AdId=-40;BnId=0;itime=559660172;kvmn=y403334;kvssp=ssp;kvrs=ydotcom:qsp:finance:ver:pt:utility:site:pct;kvpgcolo=sg3;kvy%2Dbucket=finance%2Dsg%2Den%2Dsg%2Ddef;kvadtc%5Fdvmktname=unknown;kvadtc%5Fdvosplt=unknown;kvadtc%5Fdvbrand=unknown;kvadtc%5Fdvtype=unknown;kvadtc%5Fdvmodel=unknown;kvrepo%5Fdvosplt=unknown;kvadtc%5Fdvosversion=UNKNOWN;kvadtc%5Fcrbrand=wifi%5F;kvadtc%5Fcrmcc=UNKNOWN;kvadtc%5Fcrmnc=UNKNOWN;kvadtc%5Fcontype=wifi;gdpr=0;adclntid=1004;spaceid=1187335917;" target=_top><img src="https://aka-cdn.adtechus.com/images/ATCollapse.gif" border=0 alt="AOL Ad" width="1" height="1" ></a>\');\n var adcount_4871878_1_=new Image();\nadcount_4871878_1_.src="https://sg.as.y.atwola.com/adcount|2.0|5113.1|4871878|0|0|AdId=-40;BnId=0;ct=1374990969;st=1450;adcid=1;itime=559660172;reqtype=5;;impref=1606559661131164490;imprefseq=67567253142383133;imprefts=1606559661;adclntid=1004;spaceid=1187335917;adposition=FSRVY;lmsid=;revshare=pt%253Autility%253Bsite%253Afinance%253Bver%253Aydotcom%253Bpct%253Aqsp;pvid=fUPawgAAAADL8pzkhCIjJZgSCvH411_CJ60ADRTs;sectionid=96364561;kvmn=y403334;kvssp=ssp;kvrs=ydotcom:qsp:finance:ver:pt:utility:site:pct;kvpgcolo=sg3;kvy%2Dbucket=finance%2Dsg%2Den%2Dsg%2Ddef;kvadtc%5Fdvmktname=unknown;kvadtc%5Fdvosplt=unknown;kvadtc%5Fdvbrand=unknown;kvadtc%5Fdvtype=unknown;kvadtc%5Fdvmodel=unknown;kvrepo%5Fdvosplt=unknown;kvadtc%5Fdvosversion=UNKNOWN;kvadtc%5Fcrbrand=wifi%5F;kvadtc%5Fcrmcc=UNKNOWN;kvadtc%5Fcrmnc=UNKNOWN;kvadtc%5Fcontype=wifi;gdpr=0;"; \n',
#   'document.write(\'<a href="https://sg.as.y.atwola.com/?adlink|5113.1|4871878|0|0|AdId=-40;BnId=0;itime=559660172;kvmn=y403334;kvssp=ssp;kvrs=ydotcom:qsp:finance:ver:pt:utility:site:pct;kvpgcolo=sg3;kvy%2Dbucket=finance%2Dsg%2Den%2Dsg%2Ddef;kvadtc%5Fdvmktname=unknown;kvadtc%5Fdvosplt=unknown;kvadtc%5Fdvbrand=unknown;kvadtc%5Fdvtype=unknown;kvadtc%5Fdvmodel=unknown;kvrepo%5Fdvosplt=unknown;kvadtc%5Fdvosversion=UNKNOWN;kvadtc%5Fcrbrand=wifi%5F;kvadtc%5Fcrmcc=UNKNOWN;kvadtc%5Fcrmnc=UNKNOWN;kvadtc%5Fcontype=wifi;gdpr=0;adclntid=1004;spaceid=1187335917;" target=_top><img src="https://aka-cdn.adtechus.com/images/ATCollapse.gif" border=0 alt="AOL Ad" width="1" height="1" ></a>\');\n var adcount_4871878_1_=new Image();\nadcount_4871878_1_.src="https://sg.as.y.atwola.com/adcount|2.0|5113.1|4871878|0|0|AdId=-40;BnId=0;ct=1374990969;st=1450;adcid=1;itime=559660172;reqtype=5;;impref=1606559661131164490;imprefseq=67567253142383133;imprefts=1606559661;adclntid=1004;spaceid=1187335917;adposition=FSRVY;lmsid=;revshare=pt%253Autility%253Bsite%253Afinance%253Bver%253Aydotcom%253Bpct%253Aqsp;pvid=fUPawgAAAADL8pzkhCIjJZgSCvH411_CJ60ADRTs;sectionid=96364561;kvmn=y403334;kvssp=ssp;kvrs=ydotcom:qsp:finance:ver:pt:utility:site:pct;kvpgcolo=sg3;kvy%2Dbucket=finance%2Dsg%2Den%2Dsg%2Ddef;kvadtc%5Fdvmktname=unknown;kvadtc%5Fdvosplt=unknown;kvadtc%5Fdvbrand=unknown;kvadtc%5Fdvtype=unknown;kvadtc%5Fdvmodel=unknown;kvrepo%5Fdvosplt=unknown;kvadtc%5Fdvosversion=UNKNOWN;kvadtc%5Fcrbrand=wifi%5F;kvadtc%5Fcrmcc=UNKNOWN;kvadtc%5Fcrmnc=UNKNOWN;kvadtc%5Fcontype=wifi;gdpr=0;"; \n',
#   'document.write(\'<a href="https://sg.as.y.atwola.com/?adlink|5113.1|4871878|0|0|AdId=-40;BnId=0;itime=559660172;kvmn=y403334;kvssp=ssp;kvrs=ydotcom:qsp:finance:ver:pt:utility:site:pct;kvpgcolo=sg3;kvy%2Dbucket=finance%2Dsg%2Den%2Dsg%2Ddef;kvadtc%5Fdvmktname=unknown;kvadtc%5Fdvosplt=unknown;kvadtc%5Fdvbrand=unknown;kvadtc%5Fdvtype=unknown;kvadtc%5Fdvmodel=unknown;kvrepo%5Fdvosplt=unknown;kvadtc%5Fdvosversion=UNKNOWN;kvadtc%5Fcrbrand=wifi%5F;kvadtc%5Fcrmcc=UNKNOWN;kvadtc%5Fcrmnc=UNKNOWN;kvadtc%5Fcontype=wifi;gdpr=0;adclntid=1004;spaceid=1187335917;" target=_top><img src="https://aka-cdn.adtechus.com/images/ATCollapse.gif" border=0 alt="AOL Ad" width="1" height="1" ></a>\');\n var adcount_4871878_1_=new Image();\nadcount_4871878_1_.src="https://sg.as.y.atwola.com/adcount|2.0|5113.1|4871878|0|0|AdId=-40;BnId=0;ct=1374990969;st=1450;adcid=1;itime=559660172;reqtype=5;;impref=1606559661131164490;imprefseq=67567253142383133;imprefts=1606559661;adclntid=1004;spaceid=1187335917;adposition=FSRVY;lmsid=;revshare=pt%253Autility%253Bsite%253Afinance%253Bver%253Aydotcom%253Bpct%253Aqsp;pvid=fUPawgAAAADL8pzkhCIjJZgSCvH411_CJ60ADRTs;sectionid=96364561;kvmn=y403334;kvssp=ssp;kvrs=ydotcom:qsp:finance:ver:pt:utility:site:pct;kvpgcolo=sg3;kvy%2Dbucket=finance%2Dsg%2Den%2Dsg%2Ddef;kvadtc%5Fdvmktname=unknown;kvadtc%5Fdvosplt=unknown;kvadtc%5Fdvbrand=unknown;kvadtc%5Fdvtype=unknown;kvadtc%5Fdvmodel=unknown;kvrepo%5Fdvosplt=unknown;kvadtc%5Fdvosversion=UNKNOWN;kvadtc%5Fcrbrand=wifi%5F;kvadtc%5Fcrmcc=UNKNOWN;kvadtc%5Fcrmnc=UNKNOWN;kvadtc%5Fcontype=wifi;gdpr=0;"; \n',
#   ' react-empty: 2 ',
#   ' react-empty: 2 ')]

# %%
income_stat = pd.DataFrame(is_data[0:])

# %%
income_stat
# Out:
#                                                     0  \
# 0                                              Annual
# 1                                       Total revenue
# 2                                     Cost of revenue
# 3                                        Gross profit
# 4                  Selling general and administrative
# 5                            Total operating expenses
# 6                            Operating income or loss
# 7                                    Interest expense
# 8                     Total other income/expenses net
# 9                                   Income before tax
# 10                                 Income tax expense
# 11                  Income from continuing operations
# 12                                         Net income
# 13        Net income available to common shareholders
# 14                                          Basic EPS
# 15                                        Diluted EPS
# 16                               Basic average shares
# 17                             Diluted average shares
# 18                                             EBITDA
# 19  document.write('<a href="https://sg.as.y.atwol...
#
#                                                     1  \
# 0                                                 ttm
# 1                                          17,597,000
# 2                                           7,841,000
# 3                                           9,756,000
# 4                                           5,514,000
# 5                                           8,888,000
# 6                                             868,000
# 7                                             232,000
# 8                                             582,000
# 9                                           1,265,000
# 10                                            374,000
# 11                                            891,000
# 12                                            891,000
# 13                                            891,000
# 14                                                  -
# 15                                                  -
# 16                                                  -
# 17                                                  -
# 18                                                  -
# 19  document.write('<a href="https://sg.as.y.atwol...
#
#                                                     2  \
# 0                                          30/06/2020
# 1                                          14,054,000
# 2                                           6,415,000
# 3                                           7,639,000
# 4                                           4,287,000
# 5                                           8,212,000
# 6                                            -573,000
# 7                                             208,000
# 8                                          -1,864,000
# 9                                          -2,708,000
# 10                                           -744,000
# 11                                         -1,964,000
# 12                                         -1,964,000
# 13                                         -1,964,000
# 14                                                  -
# 15                                                  -
# 16                                                  -
# 17                                                  -
# 18                                           -455,000
# 19  document.write('<a href="https://sg.as.y.atwol...
#
#                                                     3                 4  \
# 0                                          30/06/2019        30/06/2018
# 1                                          17,597,000        16,628,000
# 2                                           7,841,000         6,828,000
# 3                                           9,756,000         9,800,000
# 4                                           5,514,000         5,500,000
# 5                                           8,888,000         8,639,000
# 6                                             868,000         1,161,000
# 7                                             232,000           230,000
# 8                                             582,000           412,000
# 9                                           1,265,000         1,391,000
# 10                                            374,000           411,000
# 11                                            891,000           980,000
# 12                                            891,000           980,000
# 13                                            891,000           980,000
# 14                                               0.55              0.56
# 15                                               0.54              0.56
# 16                                          1,634,000         1,756,000
# 17                                          1,637,868         1,756,000
# 18                                          3,162,000         3,149,000
# 19  document.write('<a href="https://sg.as.y.atwol...   react-empty: 2
#
#                    5
# 0         30/06/2017
# 1         15,680,000
# 2          6,475,000
# 3          9,205,000
# 4          5,335,000
# 5          8,174,000
# 6          1,031,000
# 7            235,000
# 8            346,000
# 9          1,181,000
# 10           328,000
# 11           853,000
# 12           852,000
# 13           852,000
# 14              0.46
# 15              0.46
# 16         1,808,226
# 17         1,808,226
# 18         2,798,000
# 19   react-empty: 2

# %%
# remove the last row 

income_stat.drop(income_stat.tail(1).index, inplace=True)

# %%
income_stat.columns = income_stat.iloc[0] # Name columns to first row of dataframe
income_stat = income_stat.iloc[1:,] # start to read 1st row
income_stat = income_stat.T # transpose dataframe

income_stat.columns = income_stat.iloc[0] #Name columns to first row of dataframe
income_stat.drop(income_stat.index[0],inplace=True) #Drop first index row
# Income_st.index.name = ‘’ # Remove the index name
# Income_st.rename(index={‘ttm’: ‘12/31/2019’},inplace=True) #Rename ttm in index columns to end of the year
# Income_st = Income_st[Income_st.columns[:-5]] # remove last 5 irrelevant columns

# %%
income_stat
# Out:
# Annual     Total revenue Cost of revenue Gross profit  \
# 0
# ttm           17,597,000       7,841,000    9,756,000
# 30/06/2020    14,054,000       6,415,000    7,639,000
# 30/06/2019    17,597,000       7,841,000    9,756,000
# 30/06/2018    16,628,000       6,828,000    9,800,000
# 30/06/2017    15,680,000       6,475,000    9,205,000
#
# Annual     Selling general and administrative Total operating expenses  \
# 0
# ttm                                 5,514,000                8,888,000
# 30/06/2020                          4,287,000                8,212,000
# 30/06/2019                          5,514,000                8,888,000
# 30/06/2018                          5,500,000                8,639,000
# 30/06/2017                          5,335,000                8,174,000
#
# Annual     Operating income or loss Interest expense  \
# 0
# ttm                         868,000          232,000
# 30/06/2020                 -573,000          208,000
# 30/06/2019                  868,000          232,000
# 30/06/2018                1,161,000          230,000
# 30/06/2017                1,031,000          235,000
#
# Annual     Total other income/expenses net Income before tax  \
# 0
# ttm                                582,000         1,265,000
# 30/06/2020                      -1,864,000        -2,708,000
# 30/06/2019                         582,000         1,265,000
# 30/06/2018                         412,000         1,391,000
# 30/06/2017                         346,000         1,181,000
#
# Annual     Income tax expense Income from continuing operations  Net income  \
# 0
# ttm                   374,000                           891,000     891,000
# 30/06/2020           -744,000                        -1,964,000  -1,964,000
# 30/06/2019            374,000                           891,000     891,000
# 30/06/2018            411,000                           980,000     980,000
# 30/06/2017            328,000                           853,000     852,000
#
# Annual     Net income available to common shareholders Basic EPS Diluted EPS  \
# 0
# ttm                                            891,000         -           -
# 30/06/2020                                  -1,964,000         -           -
# 30/06/2019                                     891,000      0.55        0.54
# 30/06/2018                                     980,000      0.56        0.56
# 30/06/2017                                     852,000      0.46        0.46
#
# Annual     Basic average shares Diluted average shares     EBITDA
# 0
# ttm                           -                      -          -
# 30/06/2020                    -                      -   -455,000
# 30/06/2019            1,634,000              1,637,868  3,162,000
# 30/06/2018            1,756,000              1,756,000  3,149,000
# 30/06/2017            1,808,226              1,808,226  2,798,000

# %%
income_stat.index.name = '' # Remove the index name

# %%
income_stat
# Out:
# Annual     Total revenue Cost of revenue Gross profit  \
#
# ttm           17,597,000       7,841,000    9,756,000
# 30/06/2020    14,054,000       6,415,000    7,639,000
# 30/06/2019    17,597,000       7,841,000    9,756,000
# 30/06/2018    16,628,000       6,828,000    9,800,000
# 30/06/2017    15,680,000       6,475,000    9,205,000
#
# Annual     Selling general and administrative Total operating expenses  \
#
# ttm                                 5,514,000                8,888,000
# 30/06/2020                          4,287,000                8,212,000
# 30/06/2019                          5,514,000                8,888,000
# 30/06/2018                          5,500,000                8,639,000
# 30/06/2017                          5,335,000                8,174,000
#
# Annual     Operating income or loss Interest expense  \
#
# ttm                         868,000          232,000
# 30/06/2020                 -573,000          208,000
# 30/06/2019                  868,000          232,000
# 30/06/2018                1,161,000          230,000
# 30/06/2017                1,031,000          235,000
#
# Annual     Total other income/expenses net Income before tax  \
#
# ttm                                582,000         1,265,000
# 30/06/2020                      -1,864,000        -2,708,000
# 30/06/2019                         582,000         1,265,000
# 30/06/2018                         412,000         1,391,000
# 30/06/2017                         346,000         1,181,000
#
# Annual     Income tax expense Income from continuing operations  Net income  \
#
# ttm                   374,000                           891,000     891,000
# 30/06/2020           -744,000                        -1,964,000  -1,964,000
# 30/06/2019            374,000                           891,000     891,000
# 30/06/2018            411,000                           980,000     980,000
# 30/06/2017            328,000                           853,000     852,000
#
# Annual     Net income available to common shareholders Basic EPS Diluted EPS  \
#
# ttm                                            891,000         -           -
# 30/06/2020                                  -1,964,000         -           -
# 30/06/2019                                     891,000      0.55        0.54
# 30/06/2018                                     980,000      0.56        0.56
# 30/06/2017                                     852,000      0.46        0.46
#
# Annual     Basic average shares Diluted average shares     EBITDA
#
# ttm                           -                      -          -
# 30/06/2020                    -                      -   -455,000
# 30/06/2019            1,634,000              1,637,868  3,162,000
# 30/06/2018            1,756,000              1,756,000  3,149,000
# 30/06/2017            1,808,226              1,808,226  2,798,000

# %% [markdown]
# ### Share Price

# %%
url_hist = 'https://sg.finance.yahoo.com/quote/'+ index +'/history?p='+ index

# %%
import yfinance as yf
from yahoofinancial import YahooFinancials
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-95-38ce07716be5> in <module>
# ----> 1 import yfinance as yf
#       2 from yahoofinancial import YahooFinancials
#
# ModuleNotFoundError: No module named 'yfinance'

# %%
# Out:
#   File "<ipython-input-94-1885e238eb07>", line 1
#     $ pip install yfinance --upgrade --no-cache-dir
#     ^
# SyntaxError: invalid syntax
